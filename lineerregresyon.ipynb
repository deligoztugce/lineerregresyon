# %%
import pandas as pd

# %%
# değişken tanımlama define (fonksiyon/işlem) veya declare (değişken) variable
# isim değişkenimizin (variable) ismi, değeri (value) ise "ali"
# ali değerini isim değerine atayan operatör "="
# ilkel (primitive) veri tipleri /  diğer bütün veri tipleri bu veri tiplerinden türetilmiştir
isim = 'gizem'
# değişkenimizin tipi string yani metinsel bir ifade
yas = 25
# değişkenimizin tipi integer yani tam sayı
sicaklik = 25.5
# değişkenimizin tipi float (double) yani ondalık sayı
dogru_mu = True
# değişkenimizin tipi boolean yani doğru yanlış
# değişkenlerin tipini öğrenmek için type fonksiyonunu kullanabiliriz
type(yas)
# Out:
# int

# %%
telefon_numarasi= "05455485"
type(telefon_numarasi)
# Out:
# str

# %%
# koleksiyonlar (collections)
# listeler (list) / dizi (array)
alinacaklar_listesi = ["elma", "armut","muz", "elma"]

# kümeler (set)
alinacaklar_kümesi = {"elma", "armut", "muz", "elma"}

# sözlükler (dictionary) / hash table / map
alinacaklar_sözlüğü = { "elma": 3, "armut": 5, "muz": 2, "elma":1}
#sözcüklerin keyleri (anahtarları) uniqe olmalıdır
# yani bir sözlükte aynı keyden birden fazla olamaz
# string, integar anahtar, değer çiftlerinden oluşan bir sözlük (dictionary) dict = {key: value}
print (alinacaklar_listesi), alinacaklar_kümesi, alinacaklar_sözlüğü
# Out:
# ['elma', 'armut', 'muz', 'elma']
# (None, {'armut', 'elma', 'muz'}, {'elma': 1, 'armut': 5, 'muz': 2})

# %%
if len (isim) < 5:
    print ("isim 5 karakterden küçük")
else:
    print ("isim 5 karakterden küçük değil")
# Out:
# isim 5 karakterden küçük değil

# %%
i = 0
while i < 10 :
    print ("beni affet!", i)
    i= i+3
    print ("döngü bitti", i)
# Out:
# beni affet! 0
# döngü bitti 3
# beni affet! 3
# döngü bitti 6
# beni affet! 6
# döngü bitti 9
# beni affet! 9
# döngü bitti 12

# %%
for i in range (5,10) :
    print ("beni affet", i)
# Out:
# beni affet 5
# beni affet 6
# beni affet 7
# beni affet 8
# beni affet 9

# %%
for alinacak in alinacaklar_kümesi:
    print (alinacak)
# Out:
# elma
# muz
# armut

# %%
import pandas as pd

# %%
burcunun_verisi = pd.read_csv("reno_clio.csv")
burcunun_verisi
# Out:
#      yıl     km
# 0   1996  220.0
# 1   1996  264.0
# 2   1996  357.0
# 3   1997  270.0
# 4   1997  267.0
# ..   ...    ...
# 82  2023   20.0
# 83  2023   42.0
# 84  2024    7.0
# 85  2024   10.0
# 86  2024    8.0
#
# [87 rows x 2 columns]

# %%
# %pip install matplotlib
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt 
plt.scatter(burcunun_verisi ["yıl"], burcunun_verisi ["km"], color= "red")
plt.xlabel ("yıl")
plt.ylabel ("km")
plt.title ("yıl-km grafiği")
plt.show ()

# %%
#yeni bir sütun ekleyelim yıl stünundan 2024 çıkaralım
burcunun_verisi ["yaş"] = 2024 - burcunun_verisi ["yıl"]
burcunun_verisi.head ()
# Out:
#     yıl     km  yaş
# 0  1996  220.0   28
# 1  1996  264.0   28
# 2  1996  357.0   28
# 3  1997  270.0   27
# 4  1997  267.0   27

# %%
plt.scatter (burcunun_verisi ["yaş"], burcunun_verisi ["km"], color= "red")
plt.xlabel ("yaş")
plt.ylabel ("km")
plt.title ("yaş-km grafiği")
plt.show ()

# %%
a = 23
b = 12
def km_tahmini (yas):
    return a * yas + b

# %%
bir_yas_icin_km = km_tahmini (1)
print (bir_yas_icin_km)
# Out:
# 35

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# sci-kit learn kütüphanesini import edelim
# linear regression modelini oluşturalım

from sklearn.linear_model import LinearRegression

model = LinearRegression()
# formül y = ax + b
# a = 4, b = 5

# %%
# rasgele sayılar ile modeli eğitelim
model.fit([[1], [2], [3], [4]], [5, 9, 13, 17])
# Out:
# LinearRegression()

# %%
# modelimizi eğitelim
# x değişkenimiz yaş, y değişkenimiz km

model.fit(burcunun_verisi[["yaş"]], burcunun_verisi["km"])
# Out:
# LinearRegression()

# %%
tahmin_edilen_degerler = model.predict(burcunun_verisi[["yaş"]])
tahmin_edilen_degerler
# Out:
# array([298.54942529, 298.54942529, 298.54942529, 289.891133  ,
#        289.891133  , 289.891133  , 281.23284072, 281.23284072,
#        281.23284072, 272.57454844, 272.57454844, 272.57454844,
#        263.91625616, 263.91625616, 263.91625616, 255.25796388,
#        255.25796388, 255.25796388, 246.59967159, 246.59967159,
#        246.59967159, 237.94137931, 237.94137931, 237.94137931,
#        229.28308703, 229.28308703, 229.28308703, 220.62479475,
#        220.62479475, 220.62479475, 211.96650246, 211.96650246,
#        211.96650246, 203.30821018, 203.30821018, 203.30821018,
#        194.6499179 , 194.6499179 , 194.6499179 , 185.99162562,
#        185.99162562, 185.99162562, 177.33333333, 177.33333333,
#        177.33333333, 168.67504105, 168.67504105, 168.67504105,
#        160.01674877, 160.01674877, 160.01674877, 151.35845649,
#        151.35845649, 151.35845649, 142.7001642 , 142.7001642 ,
#        142.7001642 , 134.04187192, 134.04187192, 134.04187192,
# ...

# %%
# modelimizin parametrelerini görelim
model.coef_, model.intercept_
# Out:
# (array([8.65829228]), np.float64(56.11724137931037))

# %%
# predict 1
model.predict([[1]])
# Out:
# c:\Users\Tuğçe\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([64.77553366])

# %%
# şimdi grafiğe çizelim
plt.scatter(burcunun_verisi["yaş"], burcunun_verisi["km"], color="red")
plt.plot(burcunun_verisi["yaş"], tahmin_edilen_degerler, color="blue")
plt.xlabel("Yaş")
plt.ylabel("Km")
plt.title("Yaş-Km Grafiği")
plt.show()

# %%
oniki_yasindaki_araba = model.predict([[12]])
oniki_yasindaki_araba
# Out:
# c:\Users\Tuğçe\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([160.01674877])

# %%
burcunun_verisi.head(55).tail(15)
# Out:
#      yıl     km  yaş
# 40  2009  205.0   15
# 41  2009  225.0   15
# 42  2010  190.0   14
# 43  2010   82.0   14
# 44  2010  181.0   14
# 45  2011  151.0   13
# 46  2011  257.0   13
# 47  2011  150.0   13
# 48  2012  262.0   12
# 49  2012  126.0   12
# 50  2012  194.0   12
# 51  2013   77.0   11
# 52  2013  200.0   11
# 53  2013  180.0   11
# 54  2014  230.0   10
